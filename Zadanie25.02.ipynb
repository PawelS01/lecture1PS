# %% [markdown]
# <a href="https://colab.research.google.com/github/PawelS01/lecture1PS/blob/main/Zadanie25.02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Salary Data (2).csv')

gender_counts = df['Gender'].value_counts()

plt.figure(figsize= (10,6))
gender_counts.plot(kind='bar', color = "black")
plt.title('Liczba osób według płci')
plt.xlabel('Płeć')
plt.ylabel('Liczba osób')
plt.xticks(rotation=0)
plt.show()
